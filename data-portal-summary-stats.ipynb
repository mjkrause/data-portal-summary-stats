# %% [markdown]
# # Per-Project Summary Statistics

# %%
# !pwd
# Out:
# /home/michael/dev/data-portal-summary-stats

# %%
import os
homepath = os.path.join(os.path.expanduser("~"), 'dev/hca-summary-stats')
os.chdir(homepath)
import scanpy as sc
import numpy as np
from src.matrix_summary_stats import MatrixSummaryStats

# %%
# !pwd
# Out:
# /home/michael/dev/hca-summary-stats

# %%
sc.settings.set_figure_params(dpi=200)

# %%
matrix_service_endpoint = 'https://matrix.staging.data.humancellatlas.org/v1'
# Parameter for matrix request
feature = 'gene'
format_ = 'mtx'
project = 'Single cell transcriptome analysis of human pancreas'  # get single project
project_field = 'project.project_core.project_short_name'
min_cell_count = 300
min_cell_count_field = 'genes_detected'
list_projects_url = matrix_service_endpoint + '/filters/' + project_field
payload = {
    'feature': feature,
    'format': format_,
    'filter': {
        'op': 'and',
        'value': [
            {
                'op': '=',
                'value': project,
                'field': project_field
            },
            {
                'op': '>=',
                'value': min_cell_count,
                'field': min_cell_count_field
            }
        ]
    }
}

# %%
import requests
import time

# %%
response = requests.post(matrix_service_endpoint + '/matrix', json=payload)

# %%
requests.get(matrix_service_endpoint + '/projects').json()
# Out:
# {'message': 'Missing Authentication Token'}

# %%
while True:
    status_response = requests.get(matrix_service_endpoint + '/matrix/' +
                                   response.json()['request_id'])
    if status_response.json()['status'] == 'Complete':
        break
    print(f'{status_response.json()["status"]} ...')
    time.sleep(30)

# %%
status_response = requests.get(matrix_service_endpoint + '/matrix/' +
                                   response.json()['request_id'])

# %%
status_response.json()['matrix_url']
# Out:
# 'https://s3.amazonaws.com/dcp-matrix-service-results-staging/02f43a31-d4b4-404a-93ef-3120c20bb542.mtx.zip'

# %%
# Azul's prod endpoint for projects
url = "https://service.explore.data.humancellatlas.org/repository/projects/"
requests.get(url).json()
# Out:
# {'hits': [{'protocols': [{'libraryConstructionApproach': ['10X v2 sequencing'],
#      'instrumentManufacturerModel': ['Illumina HiSeq 4000'],
#      'pairedEnd': [False],
#      'workflow': [],
#      'assayType': []}],
#    'entryId': '74b6d569-3b11-42ef-b6b1-a0454522b4a0',
#    'projects': [{'projectTitle': '1.3 Million Brain Cells from E18 Mice',
#      'projectShortname': '1M Neurons',
#      'laboratory': ['Human Cell Atlas Data Coordination Platform'],
#      'arrayExpressAccessions': [],
#      'geoSeriesAccessions': ['GSE93421'],
#      'insdcProjectAccessions': ['SRP096558'],
#      'insdcStudyAccessions': ['PRJNA360949']}],
#    'samples': [{'sampleEntityType': ['specimens'],
#      'effectiveOrgan': ['brain'],
#      'organPart': ['cortex'],
#      'source': ['specimen_from_organism'],
#      'organ': ['brain'],
#      'id': ['E18_20161004_Brain', 'E18_20160930_Brain'],
#      'preservationMethod': ['fresh'],
#      'disease': ['normal']}],
#    'specimens': [{'id': ['E18_20161004_Brain', 'E18_20160930_Brain'],
#      'organ': ['brain'],
#      'organPart': ['cortex'],
#      'disease': ['normal'],
#      'preservationMethod': ['fresh'],
#      'source': ['specimen_from_organism']}],
#    'cellLines': [],
#    'donorOrganisms': [{'id': ['E18_20161004', 'E18_20160930'],
#      'genusSpecies': ['Mus musculus'],
#      'organismAge': ['18'],
#      'organismAgeUnit': ['day'],
#      'biologicalSex': ['unknown'],
#      'disease': None}],
#    'organoids': [],
#    'cellSuspensions': [{'organ': ['brain'],
#      'organPart': ['cortex'],
#      'selectedCellType': ['neuron'],
#      'totalCells': 1330000}],
#    'fileTypeSummaries': [{'fileType': 'fastq',
#      'count': 16377,
#      'totalSize': 3206177550920}]},
#   {'protocols': [{'libraryConstructionApproach': ['10X v2 sequencing'],
#      'instrumentManufacturerModel': ['Illumina HiSeq 2500'],
#      'pairedEnd': [False],
#      'workflow': [],
#      'assayType': []}],
#    'entryId': '1ead9700-d8c2-4cde-bb35-d9fc24047b34',
#    'projects': [{'projectTitle': '10x 1 Run Integration Test',
#      'projectShortname': 'prod/optimus/2019-08-01T12:00:49Z',
#      'laboratory': ['Department of Biology'],
#      'arrayExpressAccessions': ['E-AAAA-00'],
#      'geoSeriesAccessions': ['GSE00000'],
#      'insdcProjectAccessions': ['SRP000000'],
#      'insdcStudyAccessions': ['PRJNA000000']}],
#    'samples': [{'sampleEntityType': ['specimens'],
#      'effectiveOrgan': ['brain'],
#      'organPart': ['amygdala'],
#      'source': ['specimen_from_organism'],
#      'organ': ['brain'],
#      'id': ['specimen_ID_1'],
#      'preservationMethod': [None],
#      'disease': ['H syndrome']}],
#    'specimens': [{'id': ['specimen_ID_1'],
#      'organ': ['brain'],
#      'organPart': ['amygdala'],
#      'disease': ['H syndrome'],
#      'preservationMethod': [None],
#      'source': ['specimen_from_organism']}],
#    'cellLines': [],
#    'donorOrganisms': [{'id': ['donor_ID_1'],
#      'genusSpecies': ['Homo sapiens'],
#      'organismAge': ['20'],
#      'organismAgeUnit': ['year'],
#      'biologicalSex': ['male'],
#      'disease': None}],
#    'organoids': [],
#    'cellSuspensions': [{'organ': ['brain'],
#      'organPart': ['amygdala'],
#      'selectedCellType': [],
#      'totalCells': 5000}],
#    'fileTypeSummaries': [{'fileType': 'fastq.gz',
#      'count': 3,
#      'totalSize': 17837811}]},
#   {'protocols': [{'libraryConstructionApproach': ['inDrop'],
#      'instrumentManufacturerModel': ['Illumina HiSeq 2500'],
#      'pairedEnd': [True],
#      'workflow': [],
#      'assayType': []}],
#    'entryId': 'f86f1ab4-1fbb-4510-ae35-3ffd752d4dfc',
#    'projects': [{'projectTitle': 'A Single-Cell Transcriptomic Map of the Human and Mouse Pancreas Reveals Inter- and Intra-cell Population Structure',
#      'projectShortname': 'HumanMousePancreas',
#      'laboratory': ['Faculty of Biology',
#       'Department of Stem Cell and Regenerative Biology',
#       'Department of Systems Biology',
#       'Human Cell Atlas Data Coordination Platform',
#       'Center for the Science of Therapeutics',
#       'Department of Immunology, Faculty of Medicine'],
#      'arrayExpressAccessions': ['E-GEOD-84133'],
#      'geoSeriesAccessions': ['GSE84133'],
#      'insdcProjectAccessions': ['SRP078321'],
#      'insdcStudyAccessions': ['PRJNA328774']}],
#    'samples': [{'sampleEntityType': ['specimens'],
#      'effectiveOrgan': ['pancreas'],
#      'organPart': [],
#      'source': ['specimen_from_organism'],
#      'organ': ['pancreas'],
#      'id': ['H2_pancreas',
#       'H3_pancreas',
#       'M_C57BL/6_pancreas',
#       'M_ICR_pancreas',
#       'H4_pancreas',
#       'H1_pancreas'],
#      'preservationMethod': [None],
#      'disease': []}],
#    'specimens': [{'id': ['H2_pancreas',
#       'H3_pancreas',
#       'M_C57BL/6_pancreas',
#       'M_ICR_pancreas',
#       'H4_pancreas',
#       'H1_pancreas'],
#      'organ': ['pancreas'],
#      'organPart': [],
#      'disease': [],
#      'preservationMethod': [None],
#      'source': ['specimen_from_organism']}],
#    'cellLines': [],
#    'donorOrganisms': [{'id': ['H2',
#       'M_C57BL/6_5',
#       'H4',
#       'M_ICR_3',
#       'M_C57BL/6_4',
#       'M_ICR_2',
#       'M_ICR_1',
#       'M_C57BL/6_2',
#       'M_C57BL/6_3',
#       'H1',
#       'M_ICR_5',
#       'M_C57BL/6_1',
#       'M_ICR_4',
#       'H3'],
#      'genusSpecies': ['Homo sapiens', 'Mus musculus'],
#      'organismAge': ['51', '59', None, '17', '38'],
#      'organismAgeUnit': [None, 'year'],
#      'biologicalSex': ['female', 'unknown', 'male'],
#      'disease': None}],
#    'organoids': [],
#    'cellSuspensions': [{'organ': ['pancreas'],
#      'organPart': [],
#      'selectedCellType': ['pancreatic PP cell'],
#      'totalCells': 12404}],
#    'fileTypeSummaries': [{'fileType': 'fastq.gz',
#      'count': 38,
#      'totalSize': 418064570672}]},
#   {'protocols': [{'libraryConstructionApproach': ['10X v2 sequencing'],
#      'instrumentManufacturerModel': ['Illumina HiSeq 2500'],
#      'pairedEnd': [True],
#      'workflow': ['optimus_v1.3.1', 'optimus_v1.3.2'],
#      'assayType': []}],
#    'entryId': '005d611a-14d5-4fbf-846e-571a1f874f70',
#    'projects': [{'projectTitle': 'Assessing the relevance of organoids to model inter-individual variation',
#      'projectShortname': 'HPSI human cerebral organoids',
#      'laboratory': ['Human Cell Atlas Data Coordination Platform'],
#      'arrayExpressAccessions': [],
#      'geoSeriesAccessions': [],
#      'insdcProjectAccessions': ['ERP114427'],
#      'insdcStudyAccessions': ['PRJEB31821']}],
#    'samples': [{'sampleEntityType': ['organoids'],
#      'effectiveOrgan': ['brain'],
#      'modelOrganPart': [None],
#      'modelOrgan': ['brain'],
#      'id': ['Org_HPSI0314i-sojd_3_1',
#       'Org_HPSI0214i-kucg_2_1',
#       'Org_HPSI0214i-wibj_2_3',
#       'Org_HPSI0214i-kucg_2_2',
#       'Org_HPSI0214i-wibj_2_2',
#       'Org_HPSI0314i-sojd_3_3',
#       'Org_HPSI0314i-hoik_1_3',
#       'Org_HPSI0314i-hoik_1_1',
#       'Org_HPSI0214i-kucg_2_3',
#       'Org_HPSI0314i-sojd_3_2',
#       'Org_HPSI0314i-hoik_1_2',
#       'Org_HPSI0214i-wibj_2_1']}],
#    'specimens': [{'id': ['HPSI0314i-sojd_skin',
#       'HPSI0314i-hoik_skin',
#       'HPSI0214i-wibj_skin',
#       'HPSI0214i-kucg_skin'],
#      'organ': ['skin of body'],
#      'organPart': ['skin epidermis'],
#      'disease': ['normal'],
#      'preservationMethod': [None],
#      'source': ['specimen_from_organism']}],
#    'cellLines': [{'id': ['HPSI0314i-hoik_1',
#       'HPSI0314i-sojd_3',
#       'HPSI0214i-wibj_2',
#       'HPSI0214i-kucg_2'],
#      'cellLineType': ['induced pluripotent'],
#      'modelOrgan': ['stem cell']}],
#    'donorOrganisms': [{'id': ['HPSI0314i-sojd',
#       'HPSI0314i-hoik',
#       'HPSI0214i-kucg',
#       'HPSI0214i-wibj'],
#      'genusSpecies': ['Homo sapiens'],
#      'organismAge': ['55-59', '65-69', '40-44', '45-49'],
#      'organismAgeUnit': ['year'],
#      'biologicalSex': ['female', 'male'],
#      'disease': None}],
#    'organoids': [{'id': ['Org_HPSI0314i-sojd_3_1',
#       'Org_HPSI0214i-kucg_2_1',
#       'Org_HPSI0214i-wibj_2_3',
#       'Org_HPSI0214i-kucg_2_2',
#       'Org_HPSI0214i-wibj_2_2',
#       'Org_HPSI0314i-sojd_3_3',
#       'Org_HPSI0314i-hoik_1_3',
#       'Org_HPSI0314i-hoik_1_1',
#       'Org_HPSI0214i-kucg_2_3',
#       'Org_HPSI0314i-sojd_3_2',
#       'Org_HPSI0314i-hoik_1_2',
#       'Org_HPSI0214i-wibj_2_1'],
#      'modelOrgan': ['brain'],
#      'modelOrganPart': [None]}],
#    'cellSuspensions': [{'organ': ['brain'],
#      'organPart': [None],
#      'selectedCellType': ['neural cell'],
#      'totalCells': 19916}],
#    'fileTypeSummaries': [{'fileType': 'fastq.gz',
#      'count': 18,
#      'totalSize': 53857782294},
#     {'fileType': 'unknown', 'count': 30, 'totalSize': 641963142},
#     {'fileType': 'bam', 'count': 6, 'totalSize': 56932529172},
#     {'fileType': 'matrix', 'count': 6, 'totalSize': 888},
#     {'fileType': 'csv', 'count': 6, 'totalSize': 154340957},
#     {'fileType': 'pdf', 'count': 3, 'totalSize': 15762678}]},
#   {'protocols': [{'libraryConstructionApproach': ['MARS-seq'],
#      'instrumentManufacturerModel': ['Illumina NextSeq 500'],
#      'pairedEnd': [True],
#      'workflow': [],
#      'assayType': []}],
#    'entryId': 'a29952d9-925e-40f4-8a1c-274f118f1f51',
#    'projects': [{'projectTitle': 'Bone marrow plasma cells from hip replacement surgeries',
#      'projectShortname': 'BM_PC',
#      'laboratory': ['Human Cell Atlas Data Coordination Platform',
#       'Prof. Ido Amit'],
#      'arrayExpressAccessions': [],
#      'geoSeriesAccessions': [],
#      'insdcProjectAccessions': [],
#      'insdcStudyAccessions': []}],
#    'samples': [{'sampleEntityType': ['specimens'],
#      'effectiveOrgan': ['hematopoietic system'],
#      'organPart': ['bone marrow'],
#      'source': ['specimen_from_organism'],
#      'organ': ['hematopoietic system'],
#      'id': ['Hip17_specimen',
#       'Hip10_specimen',
#       'Hip13_specimen',
#       'Hip15_specimen',
#       'Hip16_specimen',
#       'Hip9_specimen',
#       'Hip12_specimen',
#       'Hip11_specimen',
#       'Hip5_specimen',
#       'Hip7_specimen',
#       'Hip6_specimen',
#       'Hip8_specimen'],
#      'preservationMethod': [None],
#      'disease': []}],
#    'specimens': [{'id': ['Hip17_specimen',
#       'Hip10_specimen',
#       'Hip13_specimen',
#       'Hip15_specimen',
#       'Hip16_specimen',
#       'Hip9_specimen',
#       'Hip12_specimen',
#       'Hip11_specimen',
#       'Hip5_specimen',
#       'Hip7_specimen',
#       'Hip6_specimen',
#       'Hip8_specimen'],
#      'organ': ['hematopoietic system'],
#      'organPart': ['bone marrow'],
#      'disease': [],
#      'preservationMethod': [None],
#      'source': ['specimen_from_organism']}],
#    'cellLines': [],
#    'donorOrganisms': [{'id': ['Hip7',
#       'Hip10',
#       'Hip5',
#       'Hip16',
#       'Hip6',
#       'Hip9',
#       'Hip12',
#       'Hip15',
#       'Hip13',
#       'Hip17',
#       'Hip11',
#       'Hip8'],
#      'genusSpecies': ['Homo sapiens'],
#      'organismAge': ['69',
#       '78',
#       '85',
#       '68',
#       '80',
#       '49',
#       '53',
#       '76',
#       '50',
#       '63',
#       '73'],
#      'organismAgeUnit': ['year'],
#      'biologicalSex': ['female', 'male'],
#      'disease': None}],
#    'organoids': [],
#    'cellSuspensions': [{'organ': ['hematopoietic system'],
#      'organPart': ['bone marrow'],
#      'selectedCellType': ['Plasma cell'],
#      'totalCells': 9500}],
#    'fileTypeSummaries': [{'fileType': 'fastq.gz',
#      'count': 50,
#      'totalSize': 32304816501},
#     {'fileType': 'pdf', 'count': 2, 'totalSize': 204869}]},
#   {'protocols': [{'libraryConstructionApproach': ['CITE-seq'],
#      'instrumentManufacturerModel': ['Illumina Hiseq 2500'],
#      'pairedEnd': [False],
#      'workflow': [],
#      'assayType': []}],
#    'entryId': 'f81efc03-9f56-4354-aabb-6ce819c3d414',
#    'projects': [{'projectTitle': 'Cell hashing with barcoded antibodies enables multiplexing and doublet detection for single cell genomics',
#      'projectShortname': 'Multiplexed scRNA-seq with barcoded antibodies',
#      'laboratory': ['Human Cell Atlas Data Coordination Platform',
#       'Technology Development and Innovation',
#       'Satija Lab'],
#      'arrayExpressAccessions': [],
#      'geoSeriesAccessions': [],
#      'insdcProjectAccessions': [],
#      'insdcStudyAccessions': []}],
#    'samples': [{'sampleEntityType': ['specimens'],
#      'effectiveOrgan': ['blood'],
#      'organPart': [],
#      'source': ['specimen_from_organism'],
#      'organ': ['blood'],
#      'id': ['Specimen_PBMC4',
#       'Specimen_PBMC3',
#       'Specimen_PBMC1',
#       'Specimen_PBMC2',
#       'Specimen_PBMC6',
#       'Specimen_PBMC7',
#       'Specimen_PBMC8',
#       'Specimen_PBMC5'],
#      'preservationMethod': [None],
#      'disease': []}],
#    'specimens': [{'id': ['Specimen_PBMC4',
#       'Specimen_PBMC3',
#       'Specimen_PBMC1',
#       'Specimen_PBMC2',
#       'Specimen_PBMC6',
#       'Specimen_PBMC7',
#       'Specimen_PBMC8',
#       'Specimen_PBMC5'],
#      'organ': ['blood'],
#      'organPart': [],
#      'disease': [],
#      'preservationMethod': [None],
#      'source': ['specimen_from_organism']}],
#    'cellLines': [],
#    'donorOrganisms': [{'id': ['Donor_PBMC1',
#       'Donor_PBMC3',
#       'Donor_PBMC2',
#       'Donor_PBMC6',
#       'Donor_PBMC7',
#       'Donor_PBMC8',
#       'Donor_PBMC4',
#       'Donor_PBMC5'],
#      'genusSpecies': ['Homo sapiens'],
#      'organismAge': [None],
#      'organismAgeUnit': [None],
#      'biologicalSex': ['unknown'],
#      'disease': None}],
#    'organoids': [],
#    'cellSuspensions': [{'organ': ['blood'],
#      'organPart': [],
#      'selectedCellType': ['peripheral blood mononuclear cell'],
#      'totalCells': 20000}],
#    'fileTypeSummaries': [{'fileType': 'fastq.gz',
#      'count': 6,
#      'totalSize': 83729759795}]},
#   {'protocols': [{'libraryConstructionApproach': ['10X v2 sequencing'],
#      'instrumentManufacturerModel': ['Illumina HiSeq X'],
#      'pairedEnd': [False],
#      'workflow': ['optimus_v1.3.2'],
#      'assayType': []}],
#    'entryId': 'cc95ff89-2e68-4a08-a234-480eca21ce79',
#    'projects': [{'projectTitle': 'Census of Immune Cells',
#      'projectShortname': '1M Immune Cells',
#      'laboratory': ['Human Cell Atlas Data Coordination Platform',
#       'Regev Lab'],
#      'arrayExpressAccessions': [],
#      'geoSeriesAccessions': [],
#      'insdcProjectAccessions': [],
#      'insdcStudyAccessions': []}],
#    'samples': [{'sampleEntityType': ['specimens'],
#      'effectiveOrgan': ['blood', 'immune system'],
#      'organPart': ['umbilical cord blood', 'bone marrow'],
#      'source': ['specimen_from_organism'],
#      'organ': ['blood', 'immune system'],
#      'id': ['5_BM8',
#       '4_CB5',
#       '2_BM4',
#       '1_CB6',
#       '4_CB1',
#       '4_CB4',
#       '7_BM7',
#       '4_BM2',
#       '2_CB4',
#       '4_CB6',
#       '5_BM5',
#       '1_CB4',
#       '4_CB3',
#       '5_BM3',
#       '6_BM5',
#       '6_CB8',
#       '6_BM8',
#       '1_CB3',
#       '4_BM3',
#       '2_CB3',
#       '6_CB4',
#       '4_BM1',
#       '8_BM8',
#       '8_CB6',
#       '8_BM7',
#       '7_CB8',
#       '3_CB7',
#       '5_CB3',
#       '2_BM1',
#       '5_CB8',
#       '4_CB2',
#       '8_BM6',
#       '8_BM5',
#       '6_BM7',
#       '5_CB6',
#       '5_BM2',
#       '5_BM7',
#       '2_BM7',
#       '2_BM2',
#       '6_BM4',
#       '3_CB4',
#       '3_CB6',
#       '2_CB1',
#       '8_CB4',
#       '7_BM5',
#       '2_CB6',
#       '5_CB2',
#       '3_CB8',
#       '1_CB1',
#       '7_BM2',
#       '4_BM5',
#       '6_BM6',
#       '7_BM4',
#       '7_CB5',
#       '8_BM4',
#       '8_BM1',
#       '6_CB3',
#       '5_BM4',
#       '4_BM6',
#       '1_CB8',
#       '1_BM6',
#       '1_BM2',
#       '4_CB7',
#       '7_CB3',
#       '7_BM6',
#       '3_CB2',
#       '5_BM6',
#       '1_CB5',
#       '6_CB1',
#       '3_BM8',
#       '1_BM5',
#       '3_BM5',
#       '8_CB7',
#       '8_BM2',
#       '6_BM1',
#       '3_CB5',
#       '1_BM3',
#       '6_CB2',
#       '7_BM3',
#       '8_BM3',
#       '2_CB5',
#       '2_CB2',
#       '3_BM3',
#       '7_CB7',
#       '6_BM2',
#       '3_BM1',
#       '2_BM5',
#       '4_CB8',
#       '8_CB2',
#       '2_CB7',
#       '3_BM2',
#       '7_CB2',
#       '1_CB2',
#       '8_CB1',
#       '7_CB4',
#       '7_BM1',
#       '2_CB8',
#       '7_CB1',
#       '8_CB5',
#       '1_BM7'],
#      'preservationMethod': [None],
#      'disease': []}],
#    'specimens': [{'id': ['5_BM8',
#       '4_CB5',
#       '2_BM4',
#       '1_CB6',
#       '4_CB1',
#       '4_CB4',
#       '7_BM7',
#       '4_BM2',
#       '2_CB4',
#       '4_CB6',
#       '5_BM5',
#       '1_CB4',
#       '4_CB3',
#       '5_BM3',
#       '6_BM5',
#       '6_CB8',
#       '6_BM8',
#       '1_CB3',
#       '4_BM3',
#       '2_CB3',
#       '6_CB4',
#       '4_BM1',
#       '8_BM8',
#       '8_CB6',
#       '8_BM7',
#       '7_CB8',
#       '3_CB7',
#       '5_CB3',
#       '2_BM1',
#       '5_CB8',
#       '4_CB2',
#       '8_BM6',
#       '8_BM5',
#       '6_BM7',
#       '5_CB6',
#       '5_BM2',
#       '5_BM7',
#       '2_BM7',
#       '2_BM2',
#       '6_BM4',
#       '3_CB4',
#       '3_CB6',
#       '2_CB1',
#       '8_CB4',
#       '7_BM5',
#       '2_CB6',
#       '5_CB2',
#       '3_CB8',
#       '1_CB1',
#       '7_BM2',
#       '4_BM5',
#       '6_BM6',
#       '7_BM4',
#       '7_CB5',
#       '8_BM4',
#       '8_BM1',
#       '6_CB3',
#       '5_BM4',
#       '4_BM6',
#       '1_CB8',
#       '1_BM6',
#       '1_BM2',
#       '4_CB7',
#       '7_CB3',
#       '7_BM6',
#       '3_CB2',
#       '5_BM6',
#       '1_CB5',
#       '6_CB1',
#       '3_BM8',
#       '1_BM5',
#       '3_BM5',
#       '8_CB7',
#       '8_BM2',
#       '6_BM1',
#       '3_CB5',
#       '1_BM3',
#       '6_CB2',
#       '7_BM3',
#       '8_BM3',
#       '2_CB5',
#       '2_CB2',
#       '3_BM3',
#       '7_CB7',
#       '6_BM2',
#       '3_BM1',
#       '2_BM5',
#       '4_CB8',
#       '8_CB2',
#       '2_CB7',
#       '3_BM2',
#       '7_CB2',
#       '1_CB2',
#       '8_CB1',
#       '7_CB4',
#       '7_BM1',
#       '2_CB8',
#       '7_CB1',
#       '8_CB5',
#       '1_BM7'],
#      'organ': ['blood', 'immune system'],
#      'organPart': ['umbilical cord blood', 'bone marrow'],
#      'disease': [],
#      'preservationMethod': [None],
#      'source': ['specimen_from_organism']}],
#    'cellLines': [],
#    'donorOrganisms': [{'id': ['CB5',
#       'BM1',
#       'BM3',
#       'CB7',
#       'BM4',
#       'BM2',
#       'BM5',
#       'CB3',
#       'CB2',
#       'BM7',
#       'CB4',
#       'BM6',
#       'CB8',
#       'CB6',
#       'CB1',
#       'BM8'],
#      'genusSpecies': ['Homo sapiens'],
#      'organismAge': ['36', '32', '0', '50', '29', '52', '39', '26'],
#      'organismAgeUnit': ['year'],
#      'biologicalSex': ['male', 'female'],
#      'disease': None}],
#    'organoids': [],
#    'cellSuspensions': [{'organ': ['immune system'],
#      'organPart': ['bone marrow'],
#      'selectedCellType': ['bone marrow hematopoietic cell'],
#      'totalCells': 274182},
#     {'organ': ['blood'],
#      'organPart': ['umbilical cord blood'],
#      'selectedCellType': ['cord blood hematopoietic stem cell'],
#      'totalCells': 253910}],
#    'fileTypeSummaries': [{'fileType': 'fastq.gz',
#      'count': 762,
#      'totalSize': 1306165450414},
#     {'fileType': 'unknown', 'count': 635, 'totalSize': 7219422047},
#     {'fileType': 'bam', 'count': 127, 'totalSize': 1237598776632},
#     {'fileType': 'matrix', 'count': 127, 'totalSize': 18796},
#     {'fileType': 'csv', 'count': 127, 'totalSize': 1949971768}]},
#   {'protocols': [{'libraryConstructionApproach': ['DroNc-Seq', 'Drop-Seq'],
#      'instrumentManufacturerModel': ['Illumina NextSeq 500'],
#      'pairedEnd': [True],
#      'workflow': [],
#      'assayType': []}],
#    'entryId': 'a9c022b4-c771-4468-b769-cabcf9738de3',
#    'projects': [{'projectTitle': 'Comparison, calibration, and benchmarking of high-throughput single cell RNA-Seq techniques for unbiased cell-type classification',
#      'projectShortname': 'Drop-seq, DroNc-seq, Fluidigm C1 Comparison',
#      'laboratory': ['Human Cell Atlas Data Coordination Platform',
#       'Basu',
#       'Pott'],
#      'arrayExpressAccessions': [],
#      'geoSeriesAccessions': [],
#      'insdcProjectAccessions': [],
#      'insdcStudyAccessions': []}],
#    'samples': [{'sampleEntityType': ['cellLines'],
#      'effectiveOrgan': ['heart', 'stem cell'],
#      'cellLineType': ['induced pluripotent', 'stem cell-derived'],
#      'modelOrgan': ['heart', 'stem cell'],
#      'id': ['cell_line_Day0_hiPSC-CM_BioRep1',
#       'cell_line_Day7_hiPSC-CM_BioRep1',
#       'cell_line_Day15_hiPSC-CM_BioRep2',
#       'cell_line_Day1_hiPSC-CM_BioRep1',
#       'cell_line_Day7_hiPSC-CM_BioRep2',
#       'cell_line_Day1_hiPSC-CM_BioRep2',
#       'cell_line_Day0_hiPSC-CM_BioRep2',
#       'cell_line_Day3_hiPSC-CM_BioRep1',
#       'cell_line_Day3_hiPSC-CM_BioRep2']}],
#    'specimens': [{'id': ['specimen_2', 'specimen_1'],
#      'organ': ['blood'],
#      'organPart': ['venous blood'],
#      'disease': ['normal'],
#      'preservationMethod': [None],
#      'source': ['specimen_from_organism']}],
#    'cellLines': [{'id': ['cell_line_Day0_hiPSC-CM_BioRep1',
#       'cell_line_Day7_hiPSC-CM_BioRep1',
#       'cell_line_GM18505',
#       'cell_line_Day15_hiPSC-CM_BioRep2',
#       'cell_line_Day1_hiPSC-CM_BioRep1',
#       'cell_line_Day7_hiPSC-CM_BioRep2',
#       'cell_line_Day1_hiPSC-CM_BioRep2',
#       'cell_line_Day0_hiPSC-CM_BioRep2',
#       'cell_line_GM18517',
#       'cell_line_Day3_hiPSC-CM_BioRep1',
#       'cell_line_Day3_hiPSC-CM_BioRep2'],
#      'cellLineType': ['induced pluripotent', 'stem cell-derived', 'primary'],
#      'modelOrgan': ['heart', 'blood', 'stem cell']}],
#    'donorOrganisms': [{'id': ['GM18505', 'GM18517'],
#      'genusSpecies': ['Homo sapiens'],
#      'organismAge': [None],
#      'organismAgeUnit': [None],
#      'biologicalSex': ['female'],
#      'disease': None}],
#    'organoids': [],
#    'cellSuspensions': [{'organ': ['heart'],
#      'organPart': [None],
#      'selectedCellType': [],
#      'totalCells': 0},
#     {'organ': ['stem cell'],
#      'organPart': [None],
#      'selectedCellType': [],
#      'totalCells': 0}],
#    'fileTypeSummaries': [{'fileType': 'fastq.gz',
#      'count': 44,
#      'totalSize': 158079432433}]},
#   {'protocols': [{'libraryConstructionApproach': ["10x 3' v3 sequencing"],
#      'instrumentManufacturerModel': ['Illumina NovaSeq 6000'],
#      'pairedEnd': [False],
#      'workflow': [],
#      'assayType': []}],
#    'entryId': '008e40e8-66ae-43bb-951c-c073a2fa6774',
#    'projects': [{'projectTitle': 'HDCA project: single cell transcriptomics',
#      'projectShortname': 'HDCA-Sweden-10x',
#      'laboratory': ['Unit of Molecular neurobiology'],
#      'arrayExpressAccessions': [],
#      'geoSeriesAccessions': [],
#      'insdcProjectAccessions': [],
#      'insdcStudyAccessions': []}],
#    'samples': [{'sampleEntityType': ['specimens'],
#      'effectiveOrgan': ['cerebellum', 'lung', 'heart'],
#      'organPart': ['right lung lobe', 'lobe of lung'],
#      'source': ['specimen_from_organism'],
#      'organ': ['cerebellum', 'lung', 'heart'],
#      'id': ['XDD:5743:326_Lung',
#       'XDD:0600:318_Heart',
#       'BRC2073_Cbm',
#       'XDD:5743:326_Heart',
#       'XDD:0600:318_Lung',
#       'XDD:1003:334_Lung',
#       'XHU:3565:310_Heart',
#       'XDD:1003:334_Heart'],
#      'preservationMethod': ['fresh'],
#      'disease': ['normal']}],
#    'specimens': [{'id': ['XDD:5743:326_Lung',
#       'XDD:0600:318_Heart',
#       'BRC2073_Cbm',
#       'XDD:5743:326_Heart',
#       'XDD:0600:318_Lung',
#       'XDD:1003:334_Lung',
#       'XHU:3565:310_Heart',
#       'XDD:1003:334_Heart'],
#      'organ': ['cerebellum', 'lung', 'heart'],
#      'organPart': ['right lung lobe', 'lobe of lung'],
#      'disease': ['normal'],
#      'preservationMethod': ['fresh'],
#      'source': ['specimen_from_organism']}],
#    'cellLines': [],
#    'donorOrganisms': [{'id': ['XDD:0600:318',
#       'BRC2073',
#       'XDD:5743:326',
#       'XHU:3565:310',
#       'XDD:1003:334'],
#      'genusSpecies': ['Homo sapiens'],
#      'organismAge': [None],
#      'organismAgeUnit': [None],
#      'biologicalSex': ['unknown'],
#      'disease': None}],
#    'organoids': [],
#    'cellSuspensions': [{'organ': ['heart'],
#      'organPart': [],
#      'selectedCellType': [],
#      'totalCells': 0},
#     {'organ': ['lung'],
#      'organPart': ['right lung lobe', 'lobe of lung'],
#      'selectedCellType': [],
#      'totalCells': 0},
#     {'organ': ['cerebellum'],
#      'organPart': [],
#      'selectedCellType': [],
#      'totalCells': 0}],
#    'fileTypeSummaries': [{'fileType': 'fastq.gz',
#      'count': 114,
#      'totalSize': 149125817318}]},
#   {'protocols': [{'libraryConstructionApproach': ['10X v2 sequencing'],
#      'instrumentManufacturerModel': ['Illumina HiSeq 4000'],
#      'pairedEnd': [False],
#      'workflow': ['optimus_v1.3.1', 'optimus_v1.3.2'],
#      'assayType': []}],
#    'entryId': 'c4077b3c-5c98-4d26-a614-246d12c2e5d7',
#    'projects': [{'projectTitle': 'Ischaemic sensitivity of human tissue by single cell RNA seq',
#      'projectShortname': 'Tissue stability',
#      'laboratory': ['Human Cell Atlas (Mike Stubbington)',
#       'Human Cell Atlas UK',
#       'Cambridge Biorepository for Translational Medicine',
#       'CGaP',
#       'Human Cell Atlas (Sarah Teichmann)',
#       'Human Cell Atlas Data Coordination Platform',
#       'Oliver Stegle',
#       'Teichmann Lab',
#       'Rebecca Fitzgerald',
#       'Molecular Immunity Unit, Department of Medicine'],
#      'arrayExpressAccessions': [],
#      'geoSeriesAccessions': [],
#      'insdcProjectAccessions': ['ERP114453'],
#      'insdcStudyAccessions': ['PRJEB31843']}],
#    'samples': [{'sampleEntityType': ['specimens'],
#      'effectiveOrgan': ['esophagus', 'spleen'],
#      'organPart': ['esophagus mucosa'],
#      'source': ['specimen_from_organism'],
#      'organ': ['esophagus', 'spleen'],
#      'id': ['A12-Spl-0-TL1',
#       'A15-Oes-0-TL1',
#       'A12-Oes-0-TL1',
#       'A16-Spl-0-TL1',
#       'A8-Spl-0-TL-0h',
#       'A6-Oes-1-TL1',
#       'A1-Spl-0-TL5'],
#      'preservationMethod': ['hypothermic preservation media at 2-8C'],
#      'disease': []}],
#    'specimens': [{'id': ['A12-Spl-0-TL1',
#       'A15-Oes-0-TL1',
#       'A12-Oes-0-TL1',
#       'A16-Spl-0-TL1',
#       'A8-Spl-0-TL-0h',
#       'A6-Oes-1-TL1',
#       'A1-Spl-0-TL5'],
#      'organ': ['esophagus', 'spleen'],
#      'organPart': ['esophagus mucosa'],
#      'disease': [],
#      'preservationMethod': ['hypothermic preservation media at 2-8C'],
#      'source': ['specimen_from_organism']}],
#    'cellLines': [],
#    'donorOrganisms': [{'id': ['CBTM-296C',
#       'CBTM-328C',
#       'CBTM-302C',
#       'CBTM-325C',
#       'CBTM-284C',
#       'CBTM-337C'],
#      'genusSpecies': ['Homo sapiens'],
#      'organismAge': ['55-60', '20-25', '50-55', '40-45', '30-35'],
#      'organismAgeUnit': ['year'],
#      'biologicalSex': ['male', 'female'],
#      'disease': None}],
#    'organoids': [],
#    'cellSuspensions': [{'organ': ['spleen'],
#      'organPart': [],
#      'selectedCellType': ['splenic endothelial cell'],
#      'totalCells': 12109},
#     {'organ': ['esophagus'],
#      'organPart': ['esophagus mucosa'],
#      'selectedCellType': ['epithelial cell of esophagus'],
#      'totalCells': 10001}],
#    'fileTypeSummaries': [{'fileType': 'fastq.gz',
#      'count': 21,
#      'totalSize': 132051479368},
#     {'fileType': 'unknown', 'count': 35, 'totalSize': 559751598},
#     {'fileType': 'bam', 'count': 7, 'totalSize': 122098287350},
#     {'fileType': 'matrix', 'count': 7, 'totalSize': 1036},
#     {'fileType': 'csv', 'count': 7, 'totalSize': 152987003},
#     {'fileType': 'pdf', 'count': 5, 'totalSize': 8420595}]}],
#  'pagination': {'count': 10,
#   'total': 20,
#   'size': 10,
#   'search_after': 'Ischaemic sensitivity of human tissue by single cell RNA seq',
#   'search_after_uid': 'doc#c4077b3c-5c98-4d26-a614-246d12c2e5d7',
#   'search_before': None,
#   'search_before_uid': None,
#   'pages': 2,
#   'sort': 'projectTitle',
#   'order': 'asc'},
#  'termFacets': {'organ': {'terms': [{'term': 'blood', 'count': 4},
#     {'term': 'pancreas', 'count': 4},
#     {'term': 'brain', 'count': 3},
#     {'term': 'heart', 'count': 2},
#     {'term': 'kidney', 'count': 2},
#     {'term': 'lung', 'count': 2},
#     {'term': 'skin of body', 'count': 2},
#     {'term': 'spleen', 'count': 2},
#     {'term': 'adipose tissue', 'count': 1},
#     {'term': 'bladder organ', 'count': 1},
#     {'term': 'bone tissue', 'count': 1},
#     {'term': 'cerebellum', 'count': 1},
#     {'term': 'colon', 'count': 1},
#     {'term': 'decidua', 'count': 1},
#     {'term': 'diaphragm', 'count': 1},
#     {'term': 'esophagus', 'count': 1},
#     {'term': 'hematopoietic system', 'count': 1},
#     {'term': 'immune system', 'count': 1},
#     {'term': 'large intestine', 'count': 1},
#     {'term': 'liver', 'count': 1},
#     {'term': 'lymph node', 'count': 1},
#     {'term': 'mammary gland', 'count': 1},
#     {'term': 'muscle organ', 'count': 1},
#     {'term': 'placenta', 'count': 1},
#     {'term': 'thymus', 'count': 1},
#     {'term': 'tongue', 'count': 1},
#     {'term': 'trachea', 'count': 1},
#     {'term': 'tumor', 'count': 1},
#     {'term': None, 'count': 4}],
#    'total': 20,
#    'type': 'terms'},
#   'sampleEntityType': {'terms': [{'term': 'specimens', 'count': 16},
#     {'term': 'cell_lines', 'count': 3},
#     {'term': 'organoids', 'count': 1}],
#    'total': 20,
#    'type': 'terms'},
#   'project': {'terms': [{'term': '1M Immune Cells',
#      'count': 1,
#      'projectId': ['cc95ff89-2e68-4a08-a234-480eca21ce79']},
#     {'term': '1M Neurons',
#      'count': 1,
#      'projectId': ['74b6d569-3b11-42ef-b6b1-a0454522b4a0']},
#     {'term': 'BM_PC',
#      'count': 1,
#      'projectId': ['a29952d9-925e-40f4-8a1c-274f118f1f51']},
#     {'term': 'CD4+ cytotoxic T lymphocytes',
#      'count': 1,
#      'projectId': ['90bd6933-40c0-48d4-8d76-778c103bf545']},
#     {'term': 'Drop-seq, DroNc-seq, Fluidigm C1 Comparison',
#      'count': 1,
#      'projectId': ['a9c022b4-c771-4468-b769-cabcf9738de3']},
#     {'term': 'Fetal/Maternal Interface',
#      'count': 1,
#      'projectId': ['f83165c5-e2ea-4d15-a5cf-33f3550bffde']},
#     {'term': 'HDCA-Sweden-10x',
#      'count': 1,
#      'projectId': ['008e40e8-66ae-43bb-951c-c073a2fa6774']},
#     {'term': 'HPSI human cerebral organoids',
#      'count': 1,
#      'projectId': ['005d611a-14d5-4fbf-846e-571a1f874f70']},
#     {'term': 'Healthy and type 2 diabetes pancreas',
#      'count': 1,
#      'projectId': ['ae71be1d-ddd8-4feb-9bed-24c3ddb6e1ad']},
#     {'term': 'Human Hematopoietic Profiling',
#      'count': 1,
#      'projectId': ['091cf39b-01bc-42e5-9437-f419a66c8a45']},
#     {'term': 'HumanColonicMesenchymeIBD',
#      'count': 1,
#      'projectId': ['f8aa201c-4ff1-45a4-890e-840d63459ca2']},
#     {'term': 'HumanMousePancreas',
#      'count': 1,
#      'projectId': ['f86f1ab4-1fbb-4510-ae35-3ffd752d4dfc']},
#     {'term': 'Kidney biopsy scRNA-seq',
#      'count': 1,
#      'projectId': ['027c51c6-0719-469f-a7f5-640fe57cbece']},
#     {'term': 'Mouse Melanoma',
#      'count': 1,
#      'projectId': ['8c3c290d-dfff-4553-8868-54ce45f4ba7f']},
#     {'term': 'Multiplexed scRNA-seq with barcoded antibodies',
#      'count': 1,
#      'projectId': ['f81efc03-9f56-4354-aabb-6ce819c3d414']},
#     {'term': 'Single cell RNAseq characterization of cell types produced over time in an in vitro model of human inhibitory interneuron differentiation.',
#      'count': 1,
#      'projectId': ['2043c65a-1cf8-4828-a656-9e247d4e64f1']},
#     {'term': 'Single cell transcriptome analysis of human pancreas',
#      'count': 1,
#      'projectId': ['cddab57b-6868-4be4-806f-395ed9dd635a']},
#     {'term': 'Tabula Muris',
#      'count': 1,
#      'projectId': ['e0009214-c0a0-4a7b-96e2-d6a83e966ce0']},
#     {'term': 'Tissue stability',
#      'count': 1,
#      'projectId': ['c4077b3c-5c98-4d26-a614-246d12c2e5d7']},
#     {'term': 'prod/optimus/2019-08-01T12:00:49Z',
#      'count': 1,
#      'projectId': ['1ead9700-d8c2-4cde-bb35-d9fc24047b34']}],
#    'total': 20,
#    'type': 'terms'},
#   'assayType': {'terms': [{'term': None, 'count': 20}],
#    'total': 0,
#    'type': 'terms'},
#   'instrumentManufacturerModel': {'terms': [{'term': 'Illumina HiSeq 2500',
#      'count': 9},
#     {'term': 'Illumina HiSeq 4000', 'count': 4},
#     {'term': 'Illumina NextSeq 500', 'count': 4},
#     {'term': 'Illumina HiSeq 2000', 'count': 2},
#     {'term': 'Illumina NovaSeq 6000', 'count': 2},
#     {'term': 'Illumina HiSeq X', 'count': 1},
#     {'term': 'Illumina Hiseq 2500', 'count': 1}],
#    'total': 20,
#    'type': 'terms'},
#   'institution': {'terms': [{'term': 'EMBL-EBI', 'count': 13},
#     {'term': 'EMBL-EBI European Bioinformatics Institute', 'count': 3},
#     {'term': 'University of California, Santa Cruz', 'count': 3},
#     {'term': 'University of Cambridge', 'count': 3},
#     {'term': 'Wellcome Trust Sanger Institute', 'count': 3},
#     {'term': 'Broad Institute', 'count': 2},
#     {'term': 'Karolinska Institutet', 'count': 2},
#     {'term': 'Newcastle University', 'count': 2},
#     {'term': 'University of California Santa Cruz', 'count': 2},
#     {'term': '10x Genomics, Inc.', 'count': 1},
#     {'term': 'Biohub', 'count': 1},
#     {'term': 'Celgene Corporation', 'count': 1},
#     {'term': 'DKFZ German Cancer Research Center', 'count': 1},
#     {'term': 'Harvard Medical School', 'count': 1},
#     {'term': 'Harvard University', 'count': 1},
#     {'term': 'La Jolla Institute for Allergy and Immunology', 'count': 1},
#     {'term': 'MRC Cancer Unit', 'count': 1},
#     {'term': 'Max Planck Institute for Evolutionary Anthropology', 'count': 1},
#     {'term': 'New York Genome Center', 'count': 1},
#     {'term': 'Novo Nordisk Research Centre Oxford', 'count': 1},
#     {'term': 'OncoResponse, Inc', 'count': 1},
#     {'term': 'Sloan Kettering Institute', 'count': 1},
#     {'term': 'Stanford University', 'count': 1},
#     {'term': 'Technion - Israel Institute of Technology', 'count': 1},
#     {'term': 'The Allen Institute for Brain Science', 'count': 1},
#     {'term': 'The Weizmann Institute of Science', 'count': 1},
#     {'term': 'University of California at Santa Cruz', 'count': 1},
#     {'term': 'University of Chicago', 'count': 1},
#     {'term': 'University of Helsinki', 'count': 1},
#     {'term': 'University of Oxford', 'count': 1},
#     {'term': 'Washington University in St. Louis', 'count': 1}],
#    'total': 20,
#    'type': 'terms'},
#   'donorDisease': {'terms': [{'term': None, 'count': 20}],
#    'total': 0,
#    'type': 'terms'},
#   'organismAgeUnit': {'terms': [{'term': 'year', 'count': 12},
#     {'term': 'month', 'count': 2},
#     {'term': 'week', 'count': 2},
#     {'term': 'day', 'count': 1},
#     {'term': None, 'count': 5}],
#    'total': 20,
#    'type': 'terms'},
#   'organismAge': {'terms': [{'term': '50', 'count': 3},
#     {'term': '21', 'count': 2},
#     {'term': '22', 'count': 2},
#     {'term': '29', 'count': 2},
#     {'term': '35', 'count': 2},
#     {'term': '38', 'count': 2},
#     {'term': '44', 'count': 2},
#     {'term': '52', 'count': 2},
#     {'term': '55', 'count': 2},
#     {'term': '57', 'count': 2},
#     {'term': '69', 'count': 2},
#     {'term': '0', 'count': 1},
#     {'term': '1', 'count': 1},
#     {'term': '10-12', 'count': 1},
#     {'term': '17', 'count': 1},
#     {'term': '18', 'count': 1},
#     {'term': '18-60', 'count': 1},
#     {'term': '19', 'count': 1},
#     {'term': '20', 'count': 1},
#     {'term': '20-25', 'count': 1},
#     {'term': '23', 'count': 1},
#     {'term': '25', 'count': 1},
#     {'term': '26', 'count': 1},
#     {'term': '27', 'count': 1},
#     {'term': '28', 'count': 1},
#     {'term': '3', 'count': 1},
#     {'term': '30', 'count': 1},
#     {'term': '30-35', 'count': 1},
#     {'term': '32', 'count': 1},
#     {'term': '36', 'count': 1},
#     {'term': '37', 'count': 1},
#     {'term': '39', 'count': 1},
#     {'term': '40-44', 'count': 1},
#     {'term': '40-45', 'count': 1},
#     {'term': '43', 'count': 1},
#     {'term': '45', 'count': 1},
#     {'term': '45-49', 'count': 1},
#     {'term': '48', 'count': 1},
#     {'term': '49', 'count': 1},
#     {'term': '5', 'count': 1},
#     {'term': '50-55', 'count': 1},
#     {'term': '51', 'count': 1},
#     {'term': '53', 'count': 1},
#     {'term': '54', 'count': 1},
#     {'term': '55-59', 'count': 1},
#     {'term': '55-60', 'count': 1},
#     {'term': '59', 'count': 1},
#     {'term': '6', 'count': 1},
#     {'term': '6-12', 'count': 1},
#     {'term': '63', 'count': 1},
#     {'term': '65', 'count': 1},
#     {'term': '65-69', 'count': 1},
#     {'term': '68', 'count': 1},
#     {'term': '73', 'count': 1},
#     {'term': '76', 'count': 1},
#     {'term': '78', 'count': 1},
#     {'term': '80', 'count': 1},
#     {'term': '85', 'count': 1},
#     {'term': None, 'count': 5}],
#    'total': 20,
#    'type': 'terms'},
#   'pairedEnd': {'terms': [{'term': 'false', 'count': 11},
#     {'term': 'true', 'count': 11}],
#    'total': 20,
#    'type': 'terms'},
#   'preservationMethod': {'terms': [{'term': 'fresh', 'count': 5},
#     {'term': 'cryopreservation of live cells in liquid nitrogen', 'count': 1},
#     {'term': 'cryopreservation, other', 'count': 1},
#     {'term': 'hypothermic preservation media at 2-8C', 'count': 1},
#     {'term': None, 'count': 12}],
#    'total': 20,
#    'type': 'terms'},
#   'genusSpecies': {'terms': [{'term': 'Homo sapiens', 'count': 17},
#     {'term': 'Mus musculus', 'count': 5}],
#    'total': 20,
#    'type': 'terms'},
#   'projectTitle': {'terms': [{'term': '1.3 Million Brain Cells from E18 Mice',
#      'count': 1},
#     {'term': '10x 1 Run Integration Test', 'count': 1},
#     {'term': 'A Single-Cell Transcriptomic Map of the Human and Mouse Pancreas Reveals Inter- and Intra-cell Population Structure',
#      'count': 1},
#     {'term': 'Assessing the relevance of organoids to model inter-individual variation',
#      'count': 1},
#     {'term': 'Bone marrow plasma cells from hip replacement surgeries',
#      'count': 1},
#     {'term': 'Cell hashing with barcoded antibodies enables multiplexing and doublet detection for single cell genomics',
#      'count': 1},
#     {'term': 'Census of Immune Cells', 'count': 1},
#     {'term': 'Comparison, calibration, and benchmarking of high-throughput single cell RNA-Seq techniques for unbiased cell-type classification',
#      'count': 1},
#     {'term': 'HDCA project: single cell transcriptomics', 'count': 1},
#     {'term': 'Ischaemic sensitivity of human tissue by single cell RNA seq',
#      'count': 1},
#     {'term': 'Melanoma infiltration of stromal and immune cells', 'count': 1},
#     {'term': 'Precursors of human CD4+ cytotoxic T lymphocytes identified by single-cell transcriptome analysis',
#      'count': 1},
#     {'term': 'Profiling of CD34+ cells from human bone marrow to understand hematopoiesis',
#      'count': 1},
#     {'term': 'Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics',
#      'count': 1},
#     {'term': 'Single Cell Transcriptomics of a Human Kidney Allograft Biopsy Defines a Diverse Inflammatory Response',
#      'count': 1},
#     {'term': 'Single cell transcriptome analysis of human pancreas reveals transcriptional signatures of aging and somatic mutation patterns.',
#      'count': 1},
#     {'term': 'Single-cell RNA-seq analysis  throughout a 125-day differentiation protocol that converted H1 human embryonic stem cells to a variety of ventrally-derived cell types.',
#      'count': 1},
#     {'term': 'Single-cell RNA-seq analysis of human pancreas from healthy individuals and type 2 diabetes patients',
#      'count': 1},
#     {'term': 'Structural Remodeling of the Human Colonic Mesenchyme in Inflammatory Bowel Disease',
#      'count': 1},
#     {'term': 'Tabula Muris: Transcriptomic characterization of 20 organs and tissues from Mus musculus at single cell resolution',
#      'count': 1}],
#    'total': 20,
#    'type': 'terms'},
#   'modelOrganPart': {'terms': [{'term': None, 'count': 20}],
#    'total': 0,
#    'type': 'terms'},
#   'disease': {'terms': [{'term': 'normal', 'count': 5},
#     {'term': 'H syndrome', 'count': 1},
#     {'term': 'colitis (disease)', 'count': 1},
#     {'term': 'end stage renal failure', 'count': 1},
#     {'term': 'hemolytic-uremic syndrome', 'count': 1},
#     {'term': 'orofaciodigital syndrome VIII', 'count': 1},
#     {'term': 'ulcerative colitis (disease)', 'count': 1},
#     {'term': None, 'count': 13}],
#    'total': 20,
#    'type': 'terms'},
#   'workflow': {'terms': [{'term': 'optimus_v1.3.2', 'count': 5},
#     {'term': 'optimus_v1.3.1', 'count': 4},
#     {'term': 'smartseq2_v2.3.0', 'count': 3},
#     {'term': 'smartseq2_v2.4.0', 'count': 3},
#     {'term': None, 'count': 12}],
#    'total': 20,
#    'type': 'terms'},
#   'contactName': {'terms': [{'term': 'Mallory,Ann,Freeberg', 'count': 9},
#     {'term': 'Laura,,Huerta', 'count': 4},
#     {'term': 'Danielle,,Welter', 'count': 3},
#     {'term': 'Matthew,,Green', 'count': 3},
#     {'term': 'Parisa,, Nejad', 'count': 3},
#     {'term': 'Sarah,A,Teichmann', 'count': 3},
#     {'term': 'Anja,,Fullgrabe', 'count': 2},
#     {'term': 'Mirjana,,Efremova', 'count': 2},
#     {'term': 'Roser,,Vento-Tormo', 'count': 2},
#     {'term': 'William,G,Sullivan', 'count': 2},
#     {'term': 'Abigail,,Wall', 'count': 1},
#     {'term': 'Adrian,,Veres', 'count': 1},
#     {'term': 'Agne,,Antanaviciute', 'count': 1},
#     {'term': 'Alison,,Simmons', 'count': 1},
#     {'term': 'Allon,M,Klein', 'count': 1},
#     {'term': 'Amedeo,,Vetere', 'count': 1},
#     {'term': 'Andrew,,Malone', 'count': 1},
#     {'term': 'Angel,,Nelson', 'count': 1},
#     {'term': 'Angela,,Riedel', 'count': 1},
#     {'term': 'Anindita,, Basu', 'count': 1},
#     {'term': 'Anna,,Wilbrey-Clark', 'count': 1},
#     {'term': 'Anne-Rachel,,Krogstag', 'count': 1},
#     {'term': 'Anthi,,Tsingene', 'count': 1},
#     {'term': 'Asa,,Segerstolpe', 'count': 1},
#     {'term': 'Ashley,,Moffett', 'count': 1},
#     {'term': 'Assaf Weiner', 'count': 1},
#     {'term': 'Athanasia,,Palasantza', 'count': 1},
#     {'term': 'Aubrey,L,Faust', 'count': 1},
#     {'term': 'Aviv,,Regev', 'count': 1},
#     {'term': 'Barbara,,Treutlein', 'count': 1},
#     {'term': 'Benjamin,D,Humphreys', 'count': 1},
#     {'term': 'Bidesh,,Mahata', 'count': 1},
#     {'term': 'Bo,,Li', 'count': 1},
#     {'term': 'Boaz,,Levi', 'count': 1},
#     {'term': 'Bridget,K,Wagner', 'count': 1},
#     {'term': 'Bruce,,Charles', 'count': 1},
#     {'term': 'Carol,,Thompson', 'count': 1},
#     {'term': 'Christopher,,Villarreal', 'count': 1},
#     {'term': "Dana,, Pe'er", 'count': 1},
#     {'term': 'Danielle,,Dionne', 'count': 1},
#     {'term': 'David,,Ahern', 'count': 1},
#     {'term': 'David,,Fawkner-Corbett', 'count': 1},
#     {'term': 'Douglas,A,Melton', 'count': 1},
#     {'term': 'Ed,,Lein', 'count': 1},
#     {'term': 'Elliot,,Thomsen', 'count': 1},
#     {'term': 'Elliott,,Meer', 'count': 1},
#     {'term': 'Elo,,Madissoon', 'count': 1},
#     {'term': 'Emelie,,Brown', 'count': 1},
#     {'term': 'Emily,,Relton', 'count': 1},
#     {'term': 'Eric,, Gauchat', 'count': 1},
#     {'term': 'Erinn,,Donnelly', 'count': 1},
#     {'term': 'Eshita,,Sharma', 'count': 1},
#     {'term': 'Esther,,Mellado-Gomez', 'count': 1},
#     {'term': 'Eyal David', 'count': 1},
#     {'term': 'Felix,C,Richter', 'count': 1},
#     {'term': 'Francois,,Gervais', 'count': 1},
#     {'term': 'Gozde,,Kar', 'count': 1},
#     {'term': 'Guy Ledergor', 'count': 1},
#     {'term': 'Hannah,H,Chen', 'count': 1},
#     {'term': 'Haojia,,Wu', 'count': 1},
#     {'term': 'Hashem,,Koohy', 'count': 1},
#     {'term': 'Heather,, Eckart', 'count': 1},
#     {'term': 'Ian,,Glass', 'count': 1},
#     {'term': 'Ido Amit', 'count': 1},
#     {'term': 'Itai,,Yana', 'count': 1},
#     {'term': 'J,Gray,Camp', 'count': 1},
#     {'term': 'Jacqueline,D,Shields', 'count': 1},
#     {'term': 'James,,Kinchen', 'count': 1},
#     {'term': 'Jane,,Lee', 'count': 1},
#     {'term': 'Jani,,Huuhtanen', 'count': 1},
#     {'term': 'Jennie,,Close', 'count': 1},
#     {'term': 'Jennifer,Hyoje,Ryu', 'count': 1},
#     {'term': 'Jens,,Durruthy', 'count': 1},
#     {'term': 'Jeremy,,Miller', 'count': 1},
#     {'term': 'Jhuma,,Pramanik', 'count': 1},
#     {'term': 'Jill,,Henault', 'count': 1},
#     {'term': 'Johan,,Henriksson', 'count': 1},
#     {'term': 'John,,Mich', 'count': 1},
#     {'term': 'John,,Phillips', 'count': 1},
#     {'term': 'John,D,Doe.', 'count': 1},
#     {'term': 'John,R,Ferdinand', 'count': 1},
#     {'term': 'Jonathan,,Ting', 'count': 1},
#     {'term': 'Joseph,,Gaut', 'count': 1},
#     {'term': 'Joshua,,Grimley', 'count': 1},
#     {'term': 'Julia,,Waldman', 'count': 1},
#     {'term': 'Kamal,D,Puri', 'count': 1},
#     {'term': 'Karol,,Nowicki-Osuch', 'count': 1},
#     {'term': 'Karthik,,Shekhar', 'count': 1},
#     {'term': 'Katie,, Rhodes', 'count': 1},
#     {'term': 'Kaushal,,Parikh', 'count': 1},
#     {'term': 'Kerstin,B,Meyer', 'count': 1},
#     {'term': 'Kevin,,Loudon', 'count': 1},
#     {'term': 'Kiet,,Ngo', 'count': 1},
#     {'term': 'Kohei,,Uchimura', 'count': 1},
#     {'term': 'Kourosh,,Saeb-Parsy', 'count': 1},
#     {'term': 'Krishnaa,,Mahbubani', 'count': 1},
#     {'term': 'Krzysztof,,Polanski', 'count': 1},
#     {'term': 'Laura,,Cubitt', 'count': 1},
#     {'term': 'Liam,,Bolt', 'count': 1},
#     {'term': 'Maayan,,Baron', 'count': 1},
#     {'term': 'Manu,, Setty', 'count': 1},
#     {'term': 'Marcin,,Tabaka', 'count': 1},
#     {'term': 'Marlon,,Stoeckius', 'count': 1},
#     {'term': 'Marta,,Jagielowicz', 'count': 1},
#     {'term': 'Martin, Enge', 'count': 1},
#     {'term': 'Michael,JT,Stubbington', 'count': 1},
#     {'term': 'Michal,,Slyper', 'count': 1},
#     {'term': 'Monika,S,Kowalczyk', 'count': 1},
#     {'term': 'Moustafa,,Attar', 'count': 1},
#     {'term': 'Muzlifah,,Haniffa', 'count': 1},
#     {'term': 'Muzlifah,A,Haniffa', 'count': 1},
#     {'term': 'Nadiya,,Shapovalova', 'count': 1},
#     {'term': 'Neil,,Ashley', 'count': 1},
#     {'term': 'Nikitas,,Georgakopoulos', 'count': 1},
#     {'term': 'Oliver,,Stegle', 'count': 1},
#     {'term': 'Olivia,,Fong', 'count': 1},
#     {'term': 'Orit,,Rozenblatt-Rosen', 'count': 1},
#     {'term': 'Orr,,Ashenberg', 'count': 1},
#     {'term': 'Pandurangan,,Vijayanand', 'count': 1},
#     {'term': 'Peter,,Lönnerberg', 'count': 1},
#     {'term': 'Peter,,Smibert', 'count': 1},
#     {'term': 'Phillipa,,Harding', 'count': 1},
#     {'term': 'Pisco,,Angela', 'count': 1},
#     {'term': 'Qiang,,Gong', 'count': 1},
#     {'term': 'Quin,,Wills', 'count': 1},
#     {'term': 'Rahul,,Satija', 'count': 1},
#     {'term': 'Rebecca,,Fitzgerald', 'count': 1},
#     {'term': 'Rebecca,,Hodge', 'count': 1},
#     {'term': 'Reem,, Elorbany', 'count': 1},
#     {'term': 'Renaud,,Gaujoux', 'count': 1},
#     {'term': 'Ricardo,J,Miragaia', 'count': 1},
#     {'term': 'Rickard,,Sandberg', 'count': 1},
#     {'term': 'Rory,,Bowden', 'count': 1},
#     {'term': 'Ryan,, Dohn', 'count': 1},
#     {'term': 'Sabina,,Kanton', 'count': 1},
#     {'term': 'Sai,,Ramakrishnan', 'count': 1},
#     {'term': 'Samuel,L,Wolock', 'count': 1},
#     {'term': 'Sarah,,Davidson', 'count': 1},
#     {'term': 'Sebastian,, Pott', 'count': 1},
#     {'term': 'Shai,S,Shen-Orr', 'count': 1},
#     {'term': 'Sharad,,Ramanathan', 'count': 1},
#     {'term': 'Shiwei,,Zheng', 'count': 1},
#     {'term': 'Solongo,,Ziraldo', 'count': 1},
#     {'term': 'Soraya,,Shehata', 'count': 1},
#     {'term': 'Spyros,,Darmanis', 'count': 1},
#     {'term': 'Sten,,Linnarsson', 'count': 1},
#     {'term': 'Susan,,Bort', 'count': 1},
#     {'term': 'Timothy,,Tickle', 'count': 1},
#     {'term': 'Tracey,,Andrew', 'count': 1},
#     {'term': 'Trygve,,Bakken', 'count': 1},
#     {'term': 'Tzachi,,Hagai', 'count': 1},
#     {'term': 'Vaidotas,, Kiseliovas', 'count': 1},
#     {'term': 'Vilas,,Menon', 'count': 1},
#     {'term': 'Xi,,Chen', 'count': 1},
#     {'term': 'Yuhei,,Kirita', 'count': 1},
#     {'term': 'Zhisong,,He', 'count': 1},
#     {'term': 'Zinaida, A, Perova', 'count': 1},
#     {'term': 'Zinaida,A,Perova', 'count': 1},
#     {'term': 'Zizhen,,Yao', 'count': 1}],
#    'total': 20,
#    'type': 'terms'},
#   'effectiveOrgan': {'terms': [{'term': 'brain', 'count': 5},
#     {'term': 'blood', 'count': 4},
#     {'term': 'pancreas', 'count': 4},
#     {'term': 'heart', 'count': 3},
#     {'term': 'hematopoietic system', 'count': 2},
#     {'term': 'kidney', 'count': 2},
#     {'term': 'lung', 'count': 2},
#     {'term': 'skin of body', 'count': 2},
#     {'term': 'spleen', 'count': 2},
#     {'term': 'adipose tissue', 'count': 1},
#     {'term': 'bladder organ', 'count': 1},
#     {'term': 'bone tissue', 'count': 1},
#     {'term': 'cerebellum', 'count': 1},
#     {'term': 'colon', 'count': 1},
#     {'term': 'decidua', 'count': 1},
#     {'term': 'diaphragm', 'count': 1},
#     {'term': 'esophagus', 'count': 1},
#     {'term': 'immune system', 'count': 1},
#     {'term': 'large intestine', 'count': 1},
#     {'term': 'liver', 'count': 1},
#     {'term': 'lymph node', 'count': 1},
#     {'term': 'mammary gland', 'count': 1},
#     {'term': 'muscle organ', 'count': 1},
#     {'term': 'placenta', 'count': 1},
#     {'term': 'stem cell', 'count': 1},
#     {'term': 'thymus', 'count': 1},
#     {'term': 'tongue', 'count': 1},
#     {'term': 'trachea', 'count': 1},
#     {'term': 'tumor', 'count': 1}],
#    'total': 20,
#    'type': 'terms'},
#   'organPart': {'terms': [{'term': 'bone marrow', 'count': 2},
#     {'term': 'islet of Langerhans', 'count': 2},
#     {'term': 'amygdala', 'count': 1},
#     {'term': 'cortex', 'count': 1},
#     {'term': 'cortex of kidney', 'count': 1},
#     {'term': 'esophagus mucosa', 'count': 1},
#     {'term': 'lamina propria of mucosa of colon', 'count': 1},
#     {'term': 'lobe of lung', 'count': 1},
#     {'term': 'peripheral blood mononuclear cell', 'count': 1},
#     {'term': 'right lung lobe', 'count': 1},
#     {'term': 'umbilical cord blood', 'count': 1},
#     {'term': None, 'count': 9}],
#    'total': 20,
#    'type': 'terms'},
#   'publicationTitle': {'terms': [{'term': 'A title of a publication goes here.',
#      'count': 1},
#     {'term': 'Cell Hashing with barcoded antibodies enables multiplexing and doublet detection for single cell genomics',
#      'count': 1},
#     {'term': 'Palantir characterizes cell fate continuities in human hematopoiesis',
#      'count': 1},
#     {'term': 'Precursors of human CD4+ cytotoxic T lymphocytes identified by single-cell transcriptome analysis.',
#      'count': 1},
#     {'term': 'Single cell dissection of plasma cell heterogeneity in symptomatic and asymptomatic myeloma',
#      'count': 1},
#     {'term': 'Single-Cell Analysis of Human Pancreas Reveals Transcriptional Signatures of Aging and Somatic Mutation Patterns.',
#      'count': 1},
#     {'term': 'Single-Cell Profiling of an In\xa0Vitro Model of Human Interneuron Development Reveals Temporal Dynamics of Cell Type Production and Maturation.',
#      'count': 1},
#     {'term': 'Single-Cell Transcriptome Profiling of Human Pancreatic Islets in Health and Type 2 Diabetes',
#      'count': 1},
#     {'term': 'Single-Cell Transcriptomics of a Human Kidney Allograft Biopsy Specimen Defines a Diverse Inflammatory Response',
#      'count': 1},
#     {'term': 'Single-cell RNA sequencing reveals a dynamic stromal niche within the evolving tumour microenvironment',
#      'count': 1},
#     {'term': 'Single-cell transcriptomics of 20 mouse organs creates a Tabula Muris',
#      'count': 1},
#     {'term': 'Systematic Comparison of High-throughput Single-Cell and  Single-Nucleus Transcriptomes during Cardiomyocyte Differentiation',
#      'count': 1},
#     {'term': "Transcriptional profiling of 1.3 Million Brain Cells with the Chromium Single Cell 3' Solution",
#      'count': 1},
#     {'term': 'Transcriptomic characterization of 20 organs and tissues from mouse at single cell resolution creates a Tabula Muris',
#      'count': 1},
#     {'term': None, 'count': 7}],
#    'total': 20,
#    'type': 'terms'},
#   'cellLineType': {'terms': [{'term': 'induced pluripotent', 'count': 2},
#     {'term': 'stem cell-derived', 'count': 2},
#     {'term': 'primary', 'count': 1},
#     {'term': 'stem cell', 'count': 1},
#     {'term': None, 'count': 16}],
#    'total': 20,
#    'type': 'terms'},
#   'libraryConstructionApproach': {'terms': [{'term': '10X v2 sequencing',
#      'count': 7},
#     {'term': 'Smart-seq2', 'count': 7},
#     {'term': 'inDrop', 'count': 2},
#     {'term': "10X 3' v2 sequencing", 'count': 1},
#     {'term': "10x 3' v3 sequencing", 'count': 1},
#     {'term': 'CITE-seq', 'count': 1},
#     {'term': 'DroNc-Seq', 'count': 1},
#     {'term': 'Drop-Seq', 'count': 1},
#     {'term': 'MARS-seq', 'count': 1},
#     {'term': 'Smart-Seq', 'count': 1}],
#    'total': 20,
#    'type': 'terms'},
#   'biologicalSex': {'terms': [{'term': 'male', 'count': 14},
#     {'term': 'female', 'count': 13},
#     {'term': 'unknown', 'count': 6}],
#    'total': 20,
#    'type': 'terms'},
#   'laboratory': {'terms': [{'term': 'Human Cell Atlas Data Coordination Platform',
#      'count': 17},
#     {'term': 'Molecular Atlas', 'count': 4},
#     {'term': 'Institute of Cellular Medicine', 'count': 2},
#     {'term': 'ArrayExpress', 'count': 1},
#     {'term': 'Basu', 'count': 1},
#     {'term': 'CGaP', 'count': 1},
#     {'term': 'Cambridge Biorepository for Translational Medicine', 'count': 1},
#     {'term': 'Center for the Science of Therapeutics', 'count': 1},
#     {'term': 'Centre for Trophoblast Research', 'count': 1},
#     {'term': 'Department of Biology', 'count': 1},
#     {'term': 'Department of Cell and Molecular Biology (CMB)', 'count': 1},
#     {'term': 'Department of Immunology, Faculty of Medicine', 'count': 1},
#     {'term': 'Department of Stem Cell and Regenerative Biology', 'count': 1},
#     {'term': 'Department of Systems Biology', 'count': 1},
#     {'term': 'Division of Vaccine Discovery', 'count': 1},
#     {'term': 'Faculty of Biology', 'count': 1},
#     {'term': 'Human Cell Atlas (Mike Stubbington)', 'count': 1},
#     {'term': 'Human Cell Atlas (Sarah Teichmann)', 'count': 1},
#     {'term': 'Human Cell Atlas UK', 'count': 1},
#     {'term': 'Kennedy Institute of Rheumatology', 'count': 1},
#     {'term': 'MRC Cancer Unit', 'count': 1},
#     {'term': 'MRC Human Immunology Unit, MRC Weatherall Institute of Molecular Medicine',
#      'count': 1},
#     {'term': 'Molecular Immunity Unit, Department of Medicine', 'count': 1},
#     {'term': 'Oliver Stegle', 'count': 1},
#     {'term': "Pe'er", 'count': 1},
#     {'term': 'Pott', 'count': 1},
#     {'term': 'Prof. Ido Amit', 'count': 1},
#     {'term': 'Quake', 'count': 1},
#     {'term': 'Rebecca Fitzgerald', 'count': 1},
#     {'term': 'Regev Lab', 'count': 1},
#     {'term': 'Sarah Teichmann', 'count': 1},
#     {'term': 'Satija Lab', 'count': 1},
#     {'term': 'Technology Development and Innovation', 'count': 1},
#     {'term': 'Teichmann Lab', 'count': 1},
#     {'term': "The Humphreys' Lab", 'count': 1},
#     {'term': 'Translational Development', 'count': 1},
#     {'term': 'Unit of Molecular neurobiology', 'count': 1},
#     {'term': 'Weatherall Institute of Molecular Medicine', 'count': 1},
#     {'term': 'Wellcome Trust Centre for Human Genetics', 'count': 1}],
#    'total': 20,
#    'type': 'terms'},
#   'projectDescription': {'terms': [{'term': 'Our aims are to generate a full representation of human hematopoiesis in blood and bone marrow of humans using a multi-tier and iterative collection and analysis of 200,000 cells from ten healthy human bone',
#      'count': 1},
#     {'term': None, 'count': 19}],
#    'total': 20,
#    'type': 'terms'},
#   'selectedCellType': {'terms': [{'term': 'CD8-positive, alpha-beta T cell',
#      'count': 2},
#     {'term': 'peripheral blood mononuclear cell', 'count': 2},
#     {'term': 'B cell', 'count': 1},
#     {'term': 'CAFs', 'count': 1},
#     {'term': 'CD11b+ Macrophages/monocytes', 'count': 1},
#     {'term': 'CD11b+CD11c+DC', 'count': 1},
#     {'term': 'CD11c+ DC', 'count': 1},
#     {'term': 'CD31+ endothelial', 'count': 1},
#     {'term': 'CD34-positive, CD38-negative hematopoietic stem cell',
#      'count': 1},
#     {'term': 'CD4+ T cell', 'count': 1},
#     {'term': 'CD45-', 'count': 1},
#     {'term': 'Epcam+', 'count': 1},
#     {'term': 'HLAG+', 'count': 1},
#     {'term': 'Plasma cell', 'count': 1},
#     {'term': 'T cell', 'count': 1},
#     {'term': 'bone marrow hematopoietic cell', 'count': 1},
#     {'term': 'cord blood hematopoietic stem cell', 'count': 1},
#     {'term': 'effector memory CD8-positive, alpha-beta T cell, terminally differentiated',
#      'count': 1},
#     {'term': 'endothelial cell', 'count': 1},
#     {'term': 'epithelial cell', 'count': 1},
#     {'term': 'epithelial cell of esophagus', 'count': 1},
#     {'term': 'fibroblast', 'count': 1},
#     {'term': 'inhibitory interneuron', 'count': 1},
#     {'term': 'innate lymphoid cell', 'count': 1},
#     {'term': 'leukocyte', 'count': 1},
#     {'term': 'live', 'count': 1},
#     {'term': 'monocyte', 'count': 1},
#     {'term': 'myeloid cell', 'count': 1},
#     {'term': 'myofibroblast cell', 'count': 1},
#     {'term': 'natural killer cell', 'count': 1},
#     {'term': 'neural cell', 'count': 1},
#     {'term': 'neuron', 'count': 1},
#     {'term': 'pancreatic PP cell', 'count': 1},
#     {'term': 'splenic endothelial cell', 'count': 1},
#     {'term': 'stromal cell', 'count': 1},
#     {'term': None, 'count': 6}],
#    'total': 20,
#    'type': 'terms'},
#   'fileFormat': {'terms': [{'term': 'fastq.gz', 'count': 19},
#     {'term': 'bam', 'count': 8},
#     {'term': 'csv', 'count': 8},
#     {'term': 'matrix', 'count': 8},
#     {'term': 'unknown', 'count': 6},
#     {'term': 'pdf', 'count': 5},
#     {'term': 'bai', 'count': 3},
#     {'term': 'results', 'count': 3},
#     {'term': 'txt', 'count': 3},
#     {'term': 'fastq', 'count': 1}],
#    'total': 20,
#    'type': 'terms'},
#   'modelOrgan': {'terms': [{'term': 'brain', 'count': 2},
#     {'term': 'heart', 'count': 1},
#     {'term': 'hematopoietic system', 'count': 1},
#     {'term': 'stem cell', 'count': 1},
#     {'term': None, 'count': 16}],
#    'total': 20,
#    'type': 'terms'}}}

# %%
#matrix_path = 'test/data/04b7e4ff-a4fd-4a77-9453-16cd0f7ca030.mtx.zip'
matrix_path = 'test/data/5ff7733b-916f-4cca-b466-99b1df250e25.mtx.zip'
mss = MatrixSummaryStats()

# %%
mss.matrix_zipfile_name

# %%
mss.unzip_files(path='test/data')

# %%
adata = sc.read_10x_mtx(
    './test/data/04b7e4ff-a4fd-4a77-9453-16cd0f7ca030.mtx',      # the directory with the `.mtx` file
    var_names='gene_symbols',   # use gene symbols for the variable names (variables-axis index)
    cache=True)
adata.var_names_make_unique()

# %%
adata

# %%
sc.pl.highest_expr_genes(adata, n_top=10)

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# %%
mito_genes = adata.var_names.str.startswith('MT-')
# for each cell compute fraction of counts in mito genes vs. all genes
# the `.A1` is only necessary as X is sparse (to transform to a dense array after summing)
adata.obs['percent_mito'] = np.sum(
    adata[:, mito_genes].X, axis=1).A1 / np.sum(adata.X, axis=1).A1
# add the total counts per cell as observations-annotation to adata
adata.obs['n_counts'] = adata.X.sum(axis=1).A1

# %%
sc.pl.violin(adata, ['n_genes', 'n_counts', 'percent_mito'],
             jitter=0.4, multi_panel=True)

# %%
adata.var_keys()
#group_key = adata.obs['cell_suspension.provenance.document_id']
#sc.pl.stacked_violin(adata, list(adata.var_names)[:5], swap_axis=True)
#sc.pl.stacked_violin(adata[:10], expression_variance, grouby=group_key, swap_axis=True, use_raw=False)

# %%
sc.pl.scatter(adata, x='n_counts', y='percent_mito')
sc.pl.scatter(adata, x='n_counts', y='n_genes')

# %%
adata

# %%
adata = adata[adata.obs['n_genes'] < 2500, :]
adata = adata[adata.obs['percent_mito'] < 0.05, :]

# %%
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
sc.pp.log1p(adata)  # logarithmize
adata.raw = adata   # save raw data for later use

# %% [markdown]
# ### Identify highly variable genes.

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
adata = sc.datasets.pbmc68k_reduced()  # scanpy demo data
sc.pl.highly_variable_genes(adata)
